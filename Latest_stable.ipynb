# %% [markdown]
# # Cartoon style on image folder

# %% [markdown]
# ## Setup

# %%
# set video details

video_name='orbital_the_box' 
vid='https://www.youtube.com/watch?v=IcQXy4YdFcM' # orbital - the box
# video_name='oizo' 
# vid="https://www.youtube.com/watch?v=qmsbP13xu6k" # oizo 
# video_name='techno_dark_1'
# vid='https://www.youtube.com/watch?v=lQnzf5vrK5U'
# video_name='techno_dark_2'
# vid='https://www.youtube.com/watch?v=aAMduklK3iU'
# video_name='right_here' 
# vid="https://www.youtube.com/watch?v=ub747pprmJ8" # righthere
# video_name='this_land' 
# vid="https://www.youtube.com/watch?v=FZN-yJv82Rs"
# video_name="our_love" 
# vid="https://www.youtube.com/watch?v=eyGWBTCZ3mk" # our love 
# video_name='owe_u' 
# vid="https://www.youtube.com/watch?v=OFIWstcaoLc"

# video_name='trouble'
# vid="https://www.youtube.com/watch?v=xH_Z8xb2gvs"

# set Bash vars
# !vidb={vid}
# !video_name={video_name}
# sync google drive
from google.colab import drive
import os
# root = '/content/drive/My Drive/' # google drive root
root = '/content/Cartoonizer/'

if not os.path.exists(root):
   os.mkdir(root,777)

if not os.path.exists(root+video_name+'_frames'):
  os.mkdir(root+video_name+'_frames',777)
  
# if drive is needed uncomment
# drive.mount('/content/drive',force_remount=True)
os.chdir(root)

# %% [markdown]
# ## Imports!

# %%
# imports
import time,os,glob,cv2
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import clear_output, display, Image

from moviepy.editor import VideoFileClip
#apt sheit
# !apt update
# !apt install tree

# clear_output()
repo = "CartoonGan-tensorflow"
# !git clone https://github.com/mnicnc404/{repo}.git
os.chdir(os.path.join(repo))
# !pip install youtube-dl imageio
# !pip install tensorflow-gpu==2.0.0-alpha0
# !pip install ffmpeg Imageio
# !git clone https://www.github.com/keras-team/keras-contrib.git \
    && cd keras-contrib \
    && python convert_to_tf_keras.py \
    && USE_TF_KERAS=1 python setup.py install
  
# from subprocess import call
import tensorflow as tf
tf.__version__

# clear_output()
#function defines
def resize(image,window_height = 800):
    aspect_ratio = float(image.shape[1])/float(image.shape[0])
    window_width = window_height/aspect_ratio
    image = cv2.resize(image, (int(window_height),int(window_width)))
    return image
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,622 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Get:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:12 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:13 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Packages [13.2 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:15 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,678 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,278 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [925 kB]
# Get:18 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [806 kB]
# Fetched 4,973 kB in 6s (785 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 18 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 1s (44.5 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 131183 files and directories currently installed.)
# Preparing to unpack .../tree_1.7.0-5_amd64.deb ...
# Unpacking tree (1.7.0-5) ...
# Setting up tree (1.7.0-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Cloning into 'CartoonGan-tensorflow'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (135/135), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 1577 (delta 70), reused 91 (delta 36), pack-reused 1442
# Receiving objects: 100% (1577/1577), 345.93 MiB | 13.67 MiB/s, done.
# Resolving deltas: 100% (675/675), done.
# Checking out files: 100% (425/425), done.
# Collecting youtube-dl
#   Downloading https://files.pythonhosted.org/packages/96/ce/996f5d1b72216e21e60365ce0b3fb0afdb9f11be45f6ff88da645b3be5fb/youtube_dl-2019.8.13-py2.py3-none-any.whl (1.8MB)
#      |████████████████████████████████| 1.8MB 2.7MB/s
# Installing collected packages: youtube-dl
# Successfully installed youtube-dl-2019.8.13
# Collecting tensorflow-gpu==2.0.0-alpha0
#   Downloading https://files.pythonhosted.org/packages/1a/66/32cffad095253219d53f6b6c2a436637bbe45ac4e7be0244557210dc3918/tensorflow_gpu-2.0.0a0-cp36-cp36m-manylinux1_x86_64.whl (332.1MB)
#      |████████████████████████████████| 332.1MB 70kB/s
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.2.2)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (3.7.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.0.8)
# Collecting tb-nightly<1.14.0a20190302,>=1.14.0a20190301 (from tensorflow-gpu==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/a9/51/aa1d756644bf4624c03844115e4ac4058eff77acd786b26315f051a4b195/tb_nightly-1.14.0a20190301-py3-none-any.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 29.2MB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.8.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.16.4)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.33.4)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.7.1)
# Requirement already satisfied: google-pasta>=0.1.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.1.7)
# Collecting tf-estimator-nightly<1.14.0.dev2019030116,>=1.14.0.dev2019030115 (from tensorflow-gpu==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/13/82/f16063b4eed210dc2ab057930ac1da4fbe1e91b7b051a6c8370b401e6ae7/tf_estimator_nightly-1.14.0.dev2019030115-py2.py3-none-any.whl (411kB)
#      |████████████████████████████████| 419kB 41.1MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==2.0.0-alpha0) (41.2.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==2.0.0-alpha0) (2.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow-gpu==2.0.0-alpha0) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow-gpu==2.0.0-alpha0) (0.15.5)
# Installing collected packages: tb-nightly, tf-estimator-nightly, tensorflow-gpu
# Successfully installed tb-nightly-1.14.0a20190301 tensorflow-gpu-2.0.0a0 tf-estimator-nightly-1.14.0.dev2019030115
# Collecting ffmpeg
#   Downloading https://files.pythonhosted.org/packages/f0/cc/3b7408b8ecf7c1d20ad480c3eaed7619857bf1054b690226e906fdf14258/ffmpeg-1.4.tar.gz
# Requirement already satisfied: Imageio in /usr/local/lib/python3.6/dist-packages (2.4.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from Imageio) (4.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from Imageio) (1.16.4)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->Imageio) (0.46)
# Building wheels for collected packages: ffmpeg
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-cp36-none-any.whl size=6084 sha256=e41deda9e067bfc94e2487aa6186b0b70f42d224b862d87385910d26f78c5138
#   Stored in directory: /root/.cache/pip/wheels/b6/68/c3/a05a35f647ba871e5572b9bbfc0b95fd1c6637a2219f959e7a
# Successfully built ffmpeg
# Installing collected packages: ffmpeg
# Successfully installed ffmpeg-1.4
# Cloning into 'keras-contrib'...
# warning: redirecting to https://github.com/keras-team/keras-contrib.git/
# remote: Enumerating objects: 3622, done.
# remote: Total 3622 (delta 0), reused 0 (delta 0), pack-reused 3622
# Receiving objects: 100% (3622/3622), 858.42 KiB | 1.12 MiB/s, done.
# Resolving deltas: 100% (2322/2322), done.
# Changed imports in 73 files.
# Those files were found in the directory /content/Cartoonizer/CartoonGan-tensorflow/keras-contrib
# running install
# running bdist_egg
# running egg_info
# creating tf_keras_contrib.egg-info
# writing tf_keras_contrib.egg-info/PKG-INFO
# writing dependency_links to tf_keras_contrib.egg-info/dependency_links.txt
# writing requirements to tf_keras_contrib.egg-info/requires.txt
# writing top-level names to tf_keras_contrib.egg-info/top_level.txt
# writing manifest file 'tf_keras_contrib.egg-info/SOURCES.txt'
# writing manifest file 'tf_keras_contrib.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/keras_contrib
# copying keras_contrib/__init__.py -> build/lib/keras_contrib
# creating build/lib/keras_contrib/activations
# copying keras_contrib/activations/squash.py -> build/lib/keras_contrib/activations
# copying keras_contrib/activations/__init__.py -> build/lib/keras_contrib/activations
# creating build/lib/keras_contrib/losses
# copying keras_contrib/losses/jaccard.py -> build/lib/keras_contrib/losses
# copying keras_contrib/losses/dssim.py -> build/lib/keras_contrib/losses
# copying keras_contrib/losses/crf_losses.py -> build/lib/keras_contrib/losses
# copying keras_contrib/losses/__init__.py -> build/lib/keras_contrib/losses
# creating build/lib/keras_contrib/preprocessing
# copying keras_contrib/preprocessing/__init__.py -> build/lib/keras_contrib/preprocessing
# creating build/lib/keras_contrib/utils
# copying keras_contrib/utils/save_load_utils.py -> build/lib/keras_contrib/utils
# copying keras_contrib/utils/test_utils.py -> build/lib/keras_contrib/utils
# copying keras_contrib/utils/__init__.py -> build/lib/keras_contrib/utils
# copying keras_contrib/utils/conv_utils.py -> build/lib/keras_contrib/utils
# creating build/lib/keras_contrib/metrics
# copying keras_contrib/metrics/__init__.py -> build/lib/keras_contrib/metrics
# copying keras_contrib/metrics/crf_accuracies.py -> build/lib/keras_contrib/metrics
# creating build/lib/keras_contrib/applications
# copying keras_contrib/applications/densenet.py -> build/lib/keras_contrib/applications
# copying keras_contrib/applications/wide_resnet.py -> build/lib/keras_contrib/applications
# copying keras_contrib/applications/__init__.py -> build/lib/keras_contrib/applications
# copying keras_contrib/applications/nasnet.py -> build/lib/keras_contrib/applications
# copying keras_contrib/applications/resnet.py -> build/lib/keras_contrib/applications
# creating build/lib/keras_contrib/constraints
# copying keras_contrib/constraints/__init__.py -> build/lib/keras_contrib/constraints
# copying keras_contrib/constraints/clip.py -> build/lib/keras_contrib/constraints
# creating build/lib/keras_contrib/backend
# copying keras_contrib/backend/theano_backend.py -> build/lib/keras_contrib/backend
# copying keras_contrib/backend/tensorflow_backend.py -> build/lib/keras_contrib/backend
# copying keras_contrib/backend/cntk_backend.py -> build/lib/keras_contrib/backend
# copying keras_contrib/backend/__init__.py -> build/lib/keras_contrib/backend
# copying keras_contrib/backend/numpy_backend.py -> build/lib/keras_contrib/backend
# creating build/lib/keras_contrib/initializers
# copying keras_contrib/initializers/convaware.py -> build/lib/keras_contrib/initializers
# copying keras_contrib/initializers/__init__.py -> build/lib/keras_contrib/initializers
# creating build/lib/keras_contrib/regularizers
# copying keras_contrib/regularizers/__init__.py -> build/lib/keras_contrib/regularizers
# creating build/lib/keras_contrib/optimizers
# copying keras_contrib/optimizers/ftml.py -> build/lib/keras_contrib/optimizers
# copying keras_contrib/optimizers/__init__.py -> build/lib/keras_contrib/optimizers
# copying keras_contrib/optimizers/yogi.py -> build/lib/keras_contrib/optimizers
# copying keras_contrib/optimizers/lars.py -> build/lib/keras_contrib/optimizers
# copying keras_contrib/optimizers/padam.py -> build/lib/keras_contrib/optimizers
# creating build/lib/keras_contrib/callbacks
# copying keras_contrib/callbacks/tensorboard.py -> build/lib/keras_contrib/callbacks
# copying keras_contrib/callbacks/cyclical_learning_rate.py -> build/lib/keras_contrib/callbacks
# copying keras_contrib/callbacks/__init__.py -> build/lib/keras_contrib/callbacks
# copying keras_contrib/callbacks/snapshot.py -> build/lib/keras_contrib/callbacks
# copying keras_contrib/callbacks/dead_relu_detector.py -> build/lib/keras_contrib/callbacks
# creating build/lib/keras_contrib/datasets
# copying keras_contrib/datasets/pascal_voc.py -> build/lib/keras_contrib/datasets
# copying keras_contrib/datasets/__init__.py -> build/lib/keras_contrib/datasets
# copying keras_contrib/datasets/conll2000.py -> build/lib/keras_contrib/datasets
# copying keras_contrib/datasets/coco.py -> build/lib/keras_contrib/datasets
# creating build/lib/keras_contrib/layers
# copying keras_contrib/layers/crf.py -> build/lib/keras_contrib/layers
# copying keras_contrib/layers/core.py -> build/lib/keras_contrib/layers
# copying keras_contrib/layers/__init__.py -> build/lib/keras_contrib/layers
# copying keras_contrib/layers/capsule.py -> build/lib/keras_contrib/layers
# creating build/lib/keras_contrib/wrappers
# copying keras_contrib/wrappers/__init__.py -> build/lib/keras_contrib/wrappers
# creating build/lib/keras_contrib/tests
# copying keras_contrib/tests/metrics.py -> build/lib/keras_contrib/tests
# copying keras_contrib/tests/optimizers.py -> build/lib/keras_contrib/tests
# copying keras_contrib/tests/regularizers.py -> build/lib/keras_contrib/tests
# copying keras_contrib/tests/__init__.py -> build/lib/keras_contrib/tests
# copying keras_contrib/tests/activations.py -> build/lib/keras_contrib/tests
# creating build/lib/keras_contrib/layers/advanced_activations
# copying keras_contrib/layers/advanced_activations/sinerelu.py -> build/lib/keras_contrib/layers/advanced_activations
# copying keras_contrib/layers/advanced_activations/__init__.py -> build/lib/keras_contrib/layers/advanced_activations
# copying keras_contrib/layers/advanced_activations/srelu.py -> build/lib/keras_contrib/layers/advanced_activations
# copying keras_contrib/layers/advanced_activations/pelu.py -> build/lib/keras_contrib/layers/advanced_activations
# copying keras_contrib/layers/advanced_activations/swish.py -> build/lib/keras_contrib/layers/advanced_activations
# creating build/lib/keras_contrib/layers/convolutional
# copying keras_contrib/layers/convolutional/cosineconvolution2d.py -> build/lib/keras_contrib/layers/convolutional
# copying keras_contrib/layers/convolutional/__init__.py -> build/lib/keras_contrib/layers/convolutional
# copying keras_contrib/layers/convolutional/subpixelupscaling.py -> build/lib/keras_contrib/layers/convolutional
# creating build/lib/keras_contrib/layers/normalization
# copying keras_contrib/layers/normalization/instancenormalization.py -> build/lib/keras_contrib/layers/normalization
# copying keras_contrib/layers/normalization/__init__.py -> build/lib/keras_contrib/layers/normalization
# copying keras_contrib/layers/normalization/groupnormalization.py -> build/lib/keras_contrib/layers/normalization
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/keras_contrib
# creating build/bdist.linux-x86_64/egg/keras_contrib/activations
# copying build/lib/keras_contrib/activations/squash.py -> build/bdist.linux-x86_64/egg/keras_contrib/activations
# copying build/lib/keras_contrib/activations/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/activations
# creating build/bdist.linux-x86_64/egg/keras_contrib/losses
# copying build/lib/keras_contrib/losses/jaccard.py -> build/bdist.linux-x86_64/egg/keras_contrib/losses
# copying build/lib/keras_contrib/losses/dssim.py -> build/bdist.linux-x86_64/egg/keras_contrib/losses
# copying build/lib/keras_contrib/losses/crf_losses.py -> build/bdist.linux-x86_64/egg/keras_contrib/losses
# copying build/lib/keras_contrib/losses/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/losses
# creating build/bdist.linux-x86_64/egg/keras_contrib/preprocessing
# copying build/lib/keras_contrib/preprocessing/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/preprocessing
# creating build/bdist.linux-x86_64/egg/keras_contrib/utils
# copying build/lib/keras_contrib/utils/save_load_utils.py -> build/bdist.linux-x86_64/egg/keras_contrib/utils
# copying build/lib/keras_contrib/utils/test_utils.py -> build/bdist.linux-x86_64/egg/keras_contrib/utils
# copying build/lib/keras_contrib/utils/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/utils
# copying build/lib/keras_contrib/utils/conv_utils.py -> build/bdist.linux-x86_64/egg/keras_contrib/utils
# creating build/bdist.linux-x86_64/egg/keras_contrib/metrics
# copying build/lib/keras_contrib/metrics/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/metrics
# copying build/lib/keras_contrib/metrics/crf_accuracies.py -> build/bdist.linux-x86_64/egg/keras_contrib/metrics
# creating build/bdist.linux-x86_64/egg/keras_contrib/applications
# copying build/lib/keras_contrib/applications/densenet.py -> build/bdist.linux-x86_64/egg/keras_contrib/applications
# copying build/lib/keras_contrib/applications/wide_resnet.py -> build/bdist.linux-x86_64/egg/keras_contrib/applications
# copying build/lib/keras_contrib/applications/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/applications
# copying build/lib/keras_contrib/applications/nasnet.py -> build/bdist.linux-x86_64/egg/keras_contrib/applications
# copying build/lib/keras_contrib/applications/resnet.py -> build/bdist.linux-x86_64/egg/keras_contrib/applications
# creating build/bdist.linux-x86_64/egg/keras_contrib/constraints
# copying build/lib/keras_contrib/constraints/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/constraints
# copying build/lib/keras_contrib/constraints/clip.py -> build/bdist.linux-x86_64/egg/keras_contrib/constraints
# creating build/bdist.linux-x86_64/egg/keras_contrib/backend
# copying build/lib/keras_contrib/backend/theano_backend.py -> build/bdist.linux-x86_64/egg/keras_contrib/backend
# copying build/lib/keras_contrib/backend/tensorflow_backend.py -> build/bdist.linux-x86_64/egg/keras_contrib/backend
# copying build/lib/keras_contrib/backend/cntk_backend.py -> build/bdist.linux-x86_64/egg/keras_contrib/backend
# copying build/lib/keras_contrib/backend/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/backend
# copying build/lib/keras_contrib/backend/numpy_backend.py -> build/bdist.linux-x86_64/egg/keras_contrib/backend
# creating build/bdist.linux-x86_64/egg/keras_contrib/initializers
# copying build/lib/keras_contrib/initializers/convaware.py -> build/bdist.linux-x86_64/egg/keras_contrib/initializers
# copying build/lib/keras_contrib/initializers/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/initializers
# creating build/bdist.linux-x86_64/egg/keras_contrib/regularizers
# copying build/lib/keras_contrib/regularizers/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/regularizers
# creating build/bdist.linux-x86_64/egg/keras_contrib/optimizers
# copying build/lib/keras_contrib/optimizers/ftml.py -> build/bdist.linux-x86_64/egg/keras_contrib/optimizers
# copying build/lib/keras_contrib/optimizers/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/optimizers
# copying build/lib/keras_contrib/optimizers/yogi.py -> build/bdist.linux-x86_64/egg/keras_contrib/optimizers
# copying build/lib/keras_contrib/optimizers/lars.py -> build/bdist.linux-x86_64/egg/keras_contrib/optimizers
# copying build/lib/keras_contrib/optimizers/padam.py -> build/bdist.linux-x86_64/egg/keras_contrib/optimizers
# creating build/bdist.linux-x86_64/egg/keras_contrib/callbacks
# copying build/lib/keras_contrib/callbacks/tensorboard.py -> build/bdist.linux-x86_64/egg/keras_contrib/callbacks
# copying build/lib/keras_contrib/callbacks/cyclical_learning_rate.py -> build/bdist.linux-x86_64/egg/keras_contrib/callbacks
# copying build/lib/keras_contrib/callbacks/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/callbacks
# copying build/lib/keras_contrib/callbacks/snapshot.py -> build/bdist.linux-x86_64/egg/keras_contrib/callbacks
# copying build/lib/keras_contrib/callbacks/dead_relu_detector.py -> build/bdist.linux-x86_64/egg/keras_contrib/callbacks
# copying build/lib/keras_contrib/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib
# creating build/bdist.linux-x86_64/egg/keras_contrib/datasets
# copying build/lib/keras_contrib/datasets/pascal_voc.py -> build/bdist.linux-x86_64/egg/keras_contrib/datasets
# copying build/lib/keras_contrib/datasets/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/datasets
# copying build/lib/keras_contrib/datasets/conll2000.py -> build/bdist.linux-x86_64/egg/keras_contrib/datasets
# copying build/lib/keras_contrib/datasets/coco.py -> build/bdist.linux-x86_64/egg/keras_contrib/datasets
# creating build/bdist.linux-x86_64/egg/keras_contrib/layers
# creating build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations
# copying build/lib/keras_contrib/layers/advanced_activations/sinerelu.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations
# copying build/lib/keras_contrib/layers/advanced_activations/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations
# copying build/lib/keras_contrib/layers/advanced_activations/srelu.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations
# copying build/lib/keras_contrib/layers/advanced_activations/pelu.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations
# copying build/lib/keras_contrib/layers/advanced_activations/swish.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations
# creating build/bdist.linux-x86_64/egg/keras_contrib/layers/convolutional
# copying build/lib/keras_contrib/layers/convolutional/cosineconvolution2d.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/convolutional
# copying build/lib/keras_contrib/layers/convolutional/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/convolutional
# copying build/lib/keras_contrib/layers/convolutional/subpixelupscaling.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/convolutional
# copying build/lib/keras_contrib/layers/crf.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers
# copying build/lib/keras_contrib/layers/core.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers
# copying build/lib/keras_contrib/layers/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers
# copying build/lib/keras_contrib/layers/capsule.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers
# creating build/bdist.linux-x86_64/egg/keras_contrib/layers/normalization
# copying build/lib/keras_contrib/layers/normalization/instancenormalization.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/normalization
# copying build/lib/keras_contrib/layers/normalization/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/normalization
# copying build/lib/keras_contrib/layers/normalization/groupnormalization.py -> build/bdist.linux-x86_64/egg/keras_contrib/layers/normalization
# creating build/bdist.linux-x86_64/egg/keras_contrib/wrappers
# copying build/lib/keras_contrib/wrappers/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/wrappers
# creating build/bdist.linux-x86_64/egg/keras_contrib/tests
# copying build/lib/keras_contrib/tests/metrics.py -> build/bdist.linux-x86_64/egg/keras_contrib/tests
# copying build/lib/keras_contrib/tests/optimizers.py -> build/bdist.linux-x86_64/egg/keras_contrib/tests
# copying build/lib/keras_contrib/tests/regularizers.py -> build/bdist.linux-x86_64/egg/keras_contrib/tests
# copying build/lib/keras_contrib/tests/__init__.py -> build/bdist.linux-x86_64/egg/keras_contrib/tests
# copying build/lib/keras_contrib/tests/activations.py -> build/bdist.linux-x86_64/egg/keras_contrib/tests
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/activations/squash.py to squash.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/activations/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/losses/jaccard.py to jaccard.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/losses/dssim.py to dssim.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/losses/crf_losses.py to crf_losses.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/losses/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/preprocessing/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/utils/save_load_utils.py to save_load_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/utils/test_utils.py to test_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/utils/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/utils/conv_utils.py to conv_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/metrics/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/metrics/crf_accuracies.py to crf_accuracies.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/applications/densenet.py to densenet.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/applications/wide_resnet.py to wide_resnet.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/applications/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/applications/nasnet.py to nasnet.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/applications/resnet.py to resnet.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/constraints/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/constraints/clip.py to clip.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/backend/theano_backend.py to theano_backend.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/backend/tensorflow_backend.py to tensorflow_backend.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/backend/cntk_backend.py to cntk_backend.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/backend/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/backend/numpy_backend.py to numpy_backend.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/initializers/convaware.py to convaware.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/initializers/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/regularizers/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/optimizers/ftml.py to ftml.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/optimizers/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/optimizers/yogi.py to yogi.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/optimizers/lars.py to lars.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/optimizers/padam.py to padam.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/callbacks/tensorboard.py to tensorboard.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/callbacks/cyclical_learning_rate.py to cyclical_learning_rate.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/callbacks/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/callbacks/snapshot.py to snapshot.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/callbacks/dead_relu_detector.py to dead_relu_detector.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/datasets/pascal_voc.py to pascal_voc.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/datasets/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/datasets/conll2000.py to conll2000.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/datasets/coco.py to coco.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations/sinerelu.py to sinerelu.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations/srelu.py to srelu.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations/pelu.py to pelu.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/advanced_activations/swish.py to swish.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/convolutional/cosineconvolution2d.py to cosineconvolution2d.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/convolutional/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/convolutional/subpixelupscaling.py to subpixelupscaling.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/crf.py to crf.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/core.py to core.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/capsule.py to capsule.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/normalization/instancenormalization.py to instancenormalization.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/normalization/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/layers/normalization/groupnormalization.py to groupnormalization.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/wrappers/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/tests/metrics.py to metrics.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/tests/optimizers.py to optimizers.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/tests/regularizers.py to regularizers.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/tests/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/keras_contrib/tests/activations.py to activations.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying tf_keras_contrib.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying tf_keras_contrib.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying tf_keras_contrib.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying tf_keras_contrib.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying tf_keras_contrib.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/tf_keras_contrib-2.0.8-py3.6.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing tf_keras_contrib-2.0.8-py3.6.egg
# Copying tf_keras_contrib-2.0.8-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding tf-keras-contrib 2.0.8 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/tf_keras_contrib-2.0.8-py3.6.egg
# Processing dependencies for tf-keras-contrib==2.0.8
# Finished processing dependencies for tf-keras-contrib==2.0.8

# %% [markdown]
# ## Rip the video and audio

# %%
# frame rate
framerate = 0.15
# set max img height
max_size= 600
print('FRAMERATE = '+str(round(1/framerate,2)))

# Set i/o folders
img_in_folder =  root+video_name +"_frames"
img_out_folder = root+"processed_"+video_name +"_frames"

# set original filenames
video_file= root+video_name +'.mp4'
audio_file= root+video_name +'.mp3'

print(video_file)
print(audio_file)
# !rm -r '{audio_file}'
# !rm -r '{video_file}'
# rip video from youtube
print(vid)
os.system('echo youtube-dl '+vid+' --list-formats')
# !youtube-dl {vid} --output '{video_file}' --format mp4

clip = VideoFileClip(video_file)
clip.audio.write_audiofile(root+video_name+".mp3")


#capture the video frames
vidcap = cv2.VideoCapture(video_file)
# count total frames
import imageio
vidc = imageio.get_reader(video_file,  'ffmpeg')
num_frames=vidc._meta['nframes']
# make the frames folder
if not os.path.exists(root+video_name+'_frames'):
  os.mkdir(root+video_name+'_frames')
  
# frame grab function
def getFrame(sec):
  vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
  hasFrames,image = vidcap.read()
  if hasFrames:
    cv2.imwrite(root+video_name+"_frames/image"+str(count)+".jpg", image)     # save frame as JPG file
  return hasFrames

sec = 0
FrameRate = framerate
count=1
success = getFrame(sec)
# As long as there are frames 
while success:
  count = count + 1
  frames_left = num_frames + count
  print('frames to go ' + str(frames_left))
  sec = sec + FrameRate
  sec = round(sec, 2)
  success = getFrame(sec)
# Out:
# FRAMERATE = 6.67
# /content/Cartoonizer/techno_dark_2.mp4
# /content/Cartoonizer/techno_dark_2.mp3
# https://www.youtube.com/watch?v=aAMduklK3iU
# [youtube] aAMduklK3iU: Downloading webpage
# [youtube] aAMduklK3iU: Downloading video info webpage
# [youtube] aAMduklK3iU: Downloading js player vflRUnhQH
# [youtube] aAMduklK3iU: Downloading js player vflRUnhQH
# [download] Destination: /content/Cartoonizer/techno_dark_2.mp4
# [download] 100% of 32.36MiB in 00:01
# [MoviePy] Writing audio in /content/Cartoonizer/techno_dark_2.mp3
# 100%|██████████| 8180/8180 [00:11<00:00, 694.32it/s]
# [MoviePy] Done.
# frames to go 11131
# frames to go 11132
# frames to go 11133
# frames to go 11134
# frames to go 11135
# frames to go 11136
# frames to go 11137
# frames to go 11138
# frames to go 11139
# frames to go 11140
# frames to go 11141
# frames to go 11142
# frames to go 11143
# frames to go 11144
# frames to go 11145
# frames to go 11146
# frames to go 11147
# frames to go 11148
# frames to go 11149
# frames to go 11150
# frames to go 11151
# frames to go 11152
# frames to go 11153
# frames to go 11154
# frames to go 11155
# frames to go 11156
# frames to go 11157
# frames to go 11158
# frames to go 11159
# frames to go 11160
# frames to go 11161
# frames to go 11162
# frames to go 11163
# frames to go 11164
# frames to go 11165
# frames to go 11166
# frames to go 11167
# frames to go 11168
# frames to go 11169
# frames to go 11170
# frames to go 11171
# frames to go 11172
# frames to go 11173
# frames to go 11174
# frames to go 11175
# frames to go 11176
# frames to go 11177
# frames to go 11178
# frames to go 11179
# frames to go 11180
# frames to go 11181
# frames to go 11182
# frames to go 11183
# frames to go 11184
# frames to go 11185
# frames to go 11186
# frames to go 11187
# frames to go 11188
# frames to go 11189
# frames to go 11190
# frames to go 11191
# frames to go 11192
# frames to go 11193
# frames to go 11194
# frames to go 11195
# frames to go 11196
# frames to go 11197
# frames to go 11198
# frames to go 11199
# frames to go 11200
# frames to go 11201
# frames to go 11202
# frames to go 11203
# frames to go 11204
# frames to go 11205
# frames to go 11206
# frames to go 11207
# frames to go 11208
# frames to go 11209
# frames to go 11210
# frames to go 11211
# frames to go 11212
# frames to go 11213
# frames to go 11214
# frames to go 11215
# frames to go 11216
# frames to go 11217
# frames to go 11218
# frames to go 11219
# frames to go 11220
# frames to go 11221
# frames to go 11222
# frames to go 11223
# frames to go 11224
# frames to go 11225
# frames to go 11226
# frames to go 11227
# frames to go 11228
# frames to go 11229
# frames to go 11230
# frames to go 11231
# frames to go 11232
# frames to go 11233
# frames to go 11234
# frames to go 11235
# frames to go 11236
# frames to go 11237
# frames to go 11238
# frames to go 11239
# frames to go 11240
# frames to go 11241
# frames to go 11242
# frames to go 11243
# frames to go 11244
# frames to go 11245
# frames to go 11246
# frames to go 11247
# frames to go 11248
# frames to go 11249
# frames to go 11250
# frames to go 11251
# frames to go 11252
# frames to go 11253
# frames to go 11254
# frames to go 11255
# frames to go 11256
# frames to go 11257
# frames to go 11258
# frames to go 11259
# frames to go 11260
# frames to go 11261
# frames to go 11262
# frames to go 11263
# frames to go 11264
# frames to go 11265
# frames to go 11266
# frames to go 11267
# frames to go 11268
# frames to go 11269
# frames to go 11270
# frames to go 11271
# frames to go 11272
# frames to go 11273
# frames to go 11274
# frames to go 11275
# frames to go 11276
# frames to go 11277
# frames to go 11278
# frames to go 11279
# frames to go 11280
# frames to go 11281
# frames to go 11282
# frames to go 11283
# frames to go 11284
# frames to go 11285
# frames to go 11286
# frames to go 11287
# frames to go 11288
# frames to go 11289
# frames to go 11290
# frames to go 11291
# frames to go 11292
# frames to go 11293
# frames to go 11294
# frames to go 11295
# frames to go 11296
# frames to go 11297
# frames to go 11298
# frames to go 11299
# frames to go 11300
# frames to go 11301
# frames to go 11302
# frames to go 11303
# frames to go 11304
# frames to go 11305
# frames to go 11306
# frames to go 11307
# frames to go 11308
# frames to go 11309
# frames to go 11310
# frames to go 11311
# frames to go 11312
# frames to go 11313
# frames to go 11314
# frames to go 11315
# frames to go 11316
# frames to go 11317
# frames to go 11318
# frames to go 11319
# frames to go 11320
# frames to go 11321
# frames to go 11322
# frames to go 11323
# frames to go 11324
# frames to go 11325
# frames to go 11326
# frames to go 11327
# frames to go 11328
# frames to go 11329
# frames to go 11330
# frames to go 11331
# frames to go 11332
# frames to go 11333
# frames to go 11334
# frames to go 11335
# frames to go 11336
# frames to go 11337
# frames to go 11338
# frames to go 11339
# frames to go 11340
# frames to go 11341
# frames to go 11342
# frames to go 11343
# frames to go 11344
# frames to go 11345
# frames to go 11346
# frames to go 11347
# frames to go 11348
# frames to go 11349
# frames to go 11350
# frames to go 11351
# frames to go 11352
# frames to go 11353
# frames to go 11354
# frames to go 11355
# frames to go 11356
# frames to go 11357
# frames to go 11358
# frames to go 11359
# frames to go 11360
# frames to go 11361
# frames to go 11362
# frames to go 11363
# frames to go 11364
# frames to go 11365
# frames to go 11366
# frames to go 11367
# frames to go 11368
# frames to go 11369
# frames to go 11370
# frames to go 11371
# frames to go 11372
# frames to go 11373
# frames to go 11374
# frames to go 11375
# frames to go 11376
# frames to go 11377
# frames to go 11378
# frames to go 11379
# frames to go 11380
# frames to go 11381
# frames to go 11382
# frames to go 11383
# frames to go 11384
# frames to go 11385
# frames to go 11386
# frames to go 11387
# frames to go 11388
# frames to go 11389
# frames to go 11390
# frames to go 11391
# frames to go 11392
# frames to go 11393
# frames to go 11394
# frames to go 11395
# frames to go 11396
# frames to go 11397
# frames to go 11398
# frames to go 11399
# frames to go 11400
# frames to go 11401
# frames to go 11402
# frames to go 11403
# frames to go 11404
# frames to go 11405
# frames to go 11406
# frames to go 11407
# frames to go 11408
# frames to go 11409
# frames to go 11410
# frames to go 11411
# frames to go 11412
# frames to go 11413
# frames to go 11414
# frames to go 11415
# frames to go 11416
# frames to go 11417
# frames to go 11418
# frames to go 11419
# frames to go 11420
# frames to go 11421
# frames to go 11422
# frames to go 11423
# frames to go 11424
# frames to go 11425
# frames to go 11426
# frames to go 11427
# frames to go 11428
# frames to go 11429
# frames to go 11430
# frames to go 11431
# frames to go 11432
# frames to go 11433
# frames to go 11434
# frames to go 11435
# frames to go 11436
# frames to go 11437
# frames to go 11438
# frames to go 11439
# frames to go 11440
# frames to go 11441
# frames to go 11442
# frames to go 11443
# frames to go 11444
# frames to go 11445
# frames to go 11446
# frames to go 11447
# frames to go 11448
# frames to go 11449
# frames to go 11450
# frames to go 11451
# frames to go 11452
# frames to go 11453
# frames to go 11454
# frames to go 11455
# frames to go 11456
# frames to go 11457
# frames to go 11458
# frames to go 11459
# frames to go 11460
# frames to go 11461
# frames to go 11462
# frames to go 11463
# frames to go 11464
# frames to go 11465
# frames to go 11466
# frames to go 11467
# frames to go 11468
# frames to go 11469
# frames to go 11470
# frames to go 11471
# frames to go 11472
# frames to go 11473
# frames to go 11474
# frames to go 11475
# frames to go 11476
# frames to go 11477
# frames to go 11478
# frames to go 11479
# frames to go 11480
# frames to go 11481
# frames to go 11482
# frames to go 11483
# frames to go 11484
# frames to go 11485
# frames to go 11486
# frames to go 11487
# frames to go 11488
# frames to go 11489
# frames to go 11490
# frames to go 11491
# frames to go 11492
# frames to go 11493
# frames to go 11494
# frames to go 11495
# frames to go 11496
# frames to go 11497
# frames to go 11498
# frames to go 11499
# frames to go 11500
# frames to go 11501
# frames to go 11502
# frames to go 11503
# frames to go 11504
# frames to go 11505
# frames to go 11506
# frames to go 11507
# frames to go 11508
# frames to go 11509
# frames to go 11510
# frames to go 11511
# frames to go 11512
# frames to go 11513
# frames to go 11514
# frames to go 11515
# frames to go 11516
# frames to go 11517
# frames to go 11518
# frames to go 11519
# frames to go 11520
# frames to go 11521
# frames to go 11522
# frames to go 11523
# frames to go 11524
# frames to go 11525
# frames to go 11526
# frames to go 11527
# frames to go 11528
# frames to go 11529
# frames to go 11530
# frames to go 11531
# frames to go 11532
# frames to go 11533
# frames to go 11534
# frames to go 11535
# frames to go 11536
# frames to go 11537
# frames to go 11538
# frames to go 11539
# frames to go 11540
# frames to go 11541
# frames to go 11542
# frames to go 11543
# frames to go 11544
# frames to go 11545
# frames to go 11546
# frames to go 11547
# frames to go 11548
# frames to go 11549
# frames to go 11550
# frames to go 11551
# frames to go 11552
# frames to go 11553
# frames to go 11554
# frames to go 11555
# frames to go 11556
# frames to go 11557
# frames to go 11558
# frames to go 11559
# frames to go 11560
# frames to go 11561
# frames to go 11562
# frames to go 11563
# frames to go 11564
# frames to go 11565
# frames to go 11566
# frames to go 11567
# frames to go 11568
# frames to go 11569
# frames to go 11570
# frames to go 11571
# frames to go 11572
# frames to go 11573
# frames to go 11574
# frames to go 11575
# frames to go 11576
# frames to go 11577
# frames to go 11578
# frames to go 11579
# frames to go 11580
# frames to go 11581
# frames to go 11582
# frames to go 11583
# frames to go 11584
# frames to go 11585
# frames to go 11586
# frames to go 11587
# frames to go 11588
# frames to go 11589
# frames to go 11590
# frames to go 11591
# frames to go 11592
# frames to go 11593
# frames to go 11594
# frames to go 11595
# frames to go 11596
# frames to go 11597
# frames to go 11598
# frames to go 11599
# frames to go 11600
# frames to go 11601
# frames to go 11602
# frames to go 11603
# frames to go 11604
# frames to go 11605
# frames to go 11606
# frames to go 11607
# frames to go 11608
# frames to go 11609
# frames to go 11610
# frames to go 11611
# frames to go 11612
# frames to go 11613
# frames to go 11614
# frames to go 11615
# frames to go 11616
# frames to go 11617
# frames to go 11618
# frames to go 11619
# frames to go 11620
# frames to go 11621
# frames to go 11622
# frames to go 11623
# frames to go 11624
# frames to go 11625
# frames to go 11626
# frames to go 11627
# frames to go 11628
# frames to go 11629
# frames to go 11630
# frames to go 11631
# frames to go 11632
# frames to go 11633
# frames to go 11634
# frames to go 11635
# frames to go 11636
# frames to go 11637
# frames to go 11638
# frames to go 11639
# frames to go 11640
# frames to go 11641
# frames to go 11642
# frames to go 11643
# frames to go 11644
# frames to go 11645
# frames to go 11646
# frames to go 11647
# frames to go 11648
# frames to go 11649
# frames to go 11650
# frames to go 11651
# frames to go 11652
# frames to go 11653
# frames to go 11654
# frames to go 11655
# frames to go 11656
# frames to go 11657
# frames to go 11658
# frames to go 11659
# frames to go 11660
# frames to go 11661
# frames to go 11662
# frames to go 11663
# frames to go 11664
# frames to go 11665
# frames to go 11666
# frames to go 11667
# frames to go 11668
# frames to go 11669
# frames to go 11670
# frames to go 11671
# frames to go 11672
# frames to go 11673
# frames to go 11674
# frames to go 11675
# frames to go 11676
# frames to go 11677
# frames to go 11678
# frames to go 11679
# frames to go 11680
# frames to go 11681
# frames to go 11682
# frames to go 11683
# frames to go 11684
# frames to go 11685
# frames to go 11686
# frames to go 11687
# frames to go 11688
# frames to go 11689
# frames to go 11690
# frames to go 11691
# frames to go 11692
# frames to go 11693
# frames to go 11694
# frames to go 11695
# frames to go 11696
# frames to go 11697
# frames to go 11698
# frames to go 11699
# frames to go 11700
# frames to go 11701
# frames to go 11702
# frames to go 11703
# frames to go 11704
# frames to go 11705
# frames to go 11706
# frames to go 11707
# frames to go 11708
# frames to go 11709
# frames to go 11710
# frames to go 11711
# frames to go 11712
# frames to go 11713
# frames to go 11714
# frames to go 11715
# frames to go 11716
# frames to go 11717
# frames to go 11718
# frames to go 11719
# frames to go 11720
# frames to go 11721
# frames to go 11722
# frames to go 11723
# frames to go 11724
# frames to go 11725
# frames to go 11726
# frames to go 11727
# frames to go 11728
# frames to go 11729
# frames to go 11730
# frames to go 11731
# frames to go 11732
# frames to go 11733
# frames to go 11734
# frames to go 11735
# frames to go 11736
# frames to go 11737
# frames to go 11738
# frames to go 11739
# frames to go 11740
# frames to go 11741
# frames to go 11742
# frames to go 11743
# frames to go 11744
# frames to go 11745
# frames to go 11746
# frames to go 11747
# frames to go 11748
# frames to go 11749
# frames to go 11750
# frames to go 11751
# frames to go 11752
# frames to go 11753
# frames to go 11754
# frames to go 11755
# frames to go 11756
# frames to go 11757
# frames to go 11758
# frames to go 11759
# frames to go 11760
# frames to go 11761
# frames to go 11762
# frames to go 11763
# frames to go 11764
# frames to go 11765
# frames to go 11766
# frames to go 11767
# frames to go 11768
# frames to go 11769
# frames to go 11770
# frames to go 11771
# frames to go 11772
# frames to go 11773
# frames to go 11774
# frames to go 11775
# frames to go 11776
# frames to go 11777
# frames to go 11778
# frames to go 11779
# frames to go 11780
# frames to go 11781
# frames to go 11782
# frames to go 11783
# frames to go 11784
# frames to go 11785
# frames to go 11786
# frames to go 11787
# frames to go 11788
# frames to go 11789
# frames to go 11790
# frames to go 11791
# frames to go 11792
# frames to go 11793
# frames to go 11794
# frames to go 11795
# frames to go 11796
# frames to go 11797
# frames to go 11798
# frames to go 11799
# frames to go 11800
# frames to go 11801
# frames to go 11802
# frames to go 11803
# frames to go 11804
# frames to go 11805
# frames to go 11806
# frames to go 11807
# frames to go 11808
# frames to go 11809
# frames to go 11810
# frames to go 11811
# frames to go 11812
# frames to go 11813
# frames to go 11814
# frames to go 11815
# frames to go 11816
# frames to go 11817
# frames to go 11818
# frames to go 11819
# frames to go 11820
# frames to go 11821
# frames to go 11822
# frames to go 11823
# frames to go 11824
# frames to go 11825
# frames to go 11826
# frames to go 11827
# frames to go 11828
# frames to go 11829
# frames to go 11830
# frames to go 11831
# frames to go 11832
# frames to go 11833
# frames to go 11834
# frames to go 11835
# frames to go 11836
# frames to go 11837
# frames to go 11838
# frames to go 11839
# frames to go 11840
# frames to go 11841
# frames to go 11842
# frames to go 11843
# frames to go 11844
# frames to go 11845
# frames to go 11846
# frames to go 11847
# frames to go 11848
# frames to go 11849
# frames to go 11850
# frames to go 11851
# frames to go 11852
# frames to go 11853
# frames to go 11854
# frames to go 11855
# frames to go 11856
# frames to go 11857
# frames to go 11858
# frames to go 11859
# frames to go 11860
# frames to go 11861
# frames to go 11862
# frames to go 11863
# frames to go 11864
# frames to go 11865
# frames to go 11866
# frames to go 11867
# frames to go 11868
# frames to go 11869
# frames to go 11870
# frames to go 11871
# frames to go 11872
# frames to go 11873
# frames to go 11874
# frames to go 11875
# frames to go 11876
# frames to go 11877
# frames to go 11878
# frames to go 11879
# frames to go 11880
# frames to go 11881
# frames to go 11882
# frames to go 11883
# frames to go 11884
# frames to go 11885
# frames to go 11886
# frames to go 11887
# frames to go 11888
# frames to go 11889
# frames to go 11890
# frames to go 11891
# frames to go 11892
# frames to go 11893
# frames to go 11894
# frames to go 11895
# frames to go 11896
# frames to go 11897
# frames to go 11898
# frames to go 11899
# frames to go 11900
# frames to go 11901
# frames to go 11902
# frames to go 11903
# frames to go 11904
# frames to go 11905
# frames to go 11906
# frames to go 11907
# frames to go 11908
# frames to go 11909
# frames to go 11910
# frames to go 11911
# frames to go 11912
# frames to go 11913
# frames to go 11914
# frames to go 11915
# frames to go 11916
# frames to go 11917
# frames to go 11918
# frames to go 11919
# frames to go 11920
# frames to go 11921
# frames to go 11922
# frames to go 11923
# frames to go 11924
# frames to go 11925
# frames to go 11926
# frames to go 11927
# frames to go 11928
# frames to go 11929
# frames to go 11930
# frames to go 11931
# frames to go 11932
# frames to go 11933
# frames to go 11934
# frames to go 11935
# frames to go 11936
# frames to go 11937
# frames to go 11938
# frames to go 11939
# frames to go 11940
# frames to go 11941
# frames to go 11942
# frames to go 11943
# frames to go 11944
# frames to go 11945
# frames to go 11946
# frames to go 11947
# frames to go 11948
# frames to go 11949
# frames to go 11950
# frames to go 11951
# frames to go 11952
# frames to go 11953
# frames to go 11954
# frames to go 11955
# frames to go 11956
# frames to go 11957
# frames to go 11958
# frames to go 11959
# frames to go 11960
# frames to go 11961
# frames to go 11962
# frames to go 11963
# frames to go 11964
# frames to go 11965
# frames to go 11966
# frames to go 11967
# frames to go 11968
# frames to go 11969
# frames to go 11970
# frames to go 11971
# frames to go 11972
# frames to go 11973
# frames to go 11974
# frames to go 11975
# frames to go 11976
# frames to go 11977
# frames to go 11978
# frames to go 11979
# frames to go 11980
# frames to go 11981
# frames to go 11982
# frames to go 11983
# frames to go 11984
# frames to go 11985
# frames to go 11986
# frames to go 11987
# frames to go 11988
# frames to go 11989
# frames to go 11990
# frames to go 11991
# frames to go 11992
# frames to go 11993
# frames to go 11994
# frames to go 11995
# frames to go 11996
# frames to go 11997
# frames to go 11998
# frames to go 11999
# frames to go 12000
# frames to go 12001
# frames to go 12002
# frames to go 12003
# frames to go 12004
# frames to go 12005
# frames to go 12006
# frames to go 12007
# frames to go 12008
# frames to go 12009
# frames to go 12010
# frames to go 12011
# frames to go 12012
# frames to go 12013
# frames to go 12014
# frames to go 12015
# frames to go 12016
# frames to go 12017
# frames to go 12018
# frames to go 12019
# frames to go 12020
# frames to go 12021
# frames to go 12022
# frames to go 12023
# frames to go 12024
# frames to go 12025
# frames to go 12026
# frames to go 12027
# frames to go 12028
# frames to go 12029
# frames to go 12030
# frames to go 12031
# frames to go 12032
# frames to go 12033
# frames to go 12034
# frames to go 12035
# frames to go 12036
# frames to go 12037
# frames to go 12038
# frames to go 12039
# frames to go 12040
# frames to go 12041
# frames to go 12042
# frames to go 12043
# frames to go 12044
# frames to go 12045
# frames to go 12046
# frames to go 12047
# frames to go 12048
# frames to go 12049
# frames to go 12050
# frames to go 12051
# frames to go 12052
# frames to go 12053
# frames to go 12054
# frames to go 12055
# frames to go 12056
# frames to go 12057
# frames to go 12058
# frames to go 12059
# frames to go 12060
# frames to go 12061
# frames to go 12062
# frames to go 12063
# frames to go 12064
# frames to go 12065
# frames to go 12066
# frames to go 12067
# frames to go 12068
# frames to go 12069
# frames to go 12070
# frames to go 12071
# frames to go 12072
# frames to go 12073
# frames to go 12074
# frames to go 12075
# frames to go 12076
# frames to go 12077
# frames to go 12078
# frames to go 12079
# frames to go 12080
# frames to go 12081
# frames to go 12082
# frames to go 12083
# frames to go 12084
# frames to go 12085
# frames to go 12086
# frames to go 12087
# frames to go 12088
# frames to go 12089
# frames to go 12090
# frames to go 12091
# frames to go 12092
# frames to go 12093
# frames to go 12094
# frames to go 12095
# frames to go 12096
# frames to go 12097
# frames to go 12098
# frames to go 12099
# frames to go 12100
# frames to go 12101
# frames to go 12102
# frames to go 12103
# frames to go 12104
# frames to go 12105
# frames to go 12106
# frames to go 12107
# frames to go 12108
# frames to go 12109
# frames to go 12110
# frames to go 12111
# frames to go 12112
# frames to go 12113
# frames to go 12114
# frames to go 12115
# frames to go 12116
# frames to go 12117
# frames to go 12118
# frames to go 12119
# frames to go 12120
# frames to go 12121
# frames to go 12122
# frames to go 12123
# frames to go 12124
# frames to go 12125
# frames to go 12126
# frames to go 12127
# frames to go 12128
# frames to go 12129
# frames to go 12130
# frames to go 12131
# frames to go 12132
# frames to go 12133
# frames to go 12134
# frames to go 12135
# frames to go 12136
# frames to go 12137
# frames to go 12138
# frames to go 12139
# frames to go 12140
# frames to go 12141
# frames to go 12142
# frames to go 12143
# frames to go 12144
# frames to go 12145
# frames to go 12146
# frames to go 12147
# frames to go 12148
# frames to go 12149
# frames to go 12150
# frames to go 12151
# frames to go 12152
# frames to go 12153
# frames to go 12154
# frames to go 12155
# frames to go 12156
# frames to go 12157
# frames to go 12158
# frames to go 12159
# frames to go 12160
# frames to go 12161
# frames to go 12162
# frames to go 12163
# frames to go 12164
# frames to go 12165
# frames to go 12166
# frames to go 12167
# frames to go 12168
# frames to go 12169
# frames to go 12170
# frames to go 12171
# frames to go 12172
# frames to go 12173
# frames to go 12174
# frames to go 12175
# frames to go 12176
# frames to go 12177
# frames to go 12178
# frames to go 12179
# frames to go 12180
# frames to go 12181
# frames to go 12182
# frames to go 12183
# frames to go 12184
# frames to go 12185
# frames to go 12186
# frames to go 12187
# frames to go 12188
# frames to go 12189
# frames to go 12190
# frames to go 12191
# frames to go 12192
# frames to go 12193
# frames to go 12194
# frames to go 12195
# frames to go 12196
# frames to go 12197
# frames to go 12198
# frames to go 12199
# frames to go 12200
# frames to go 12201
# frames to go 12202
# frames to go 12203
# frames to go 12204
# frames to go 12205
# frames to go 12206
# frames to go 12207
# frames to go 12208
# frames to go 12209
# frames to go 12210
# frames to go 12211
# frames to go 12212
# frames to go 12213
# frames to go 12214
# frames to go 12215
# frames to go 12216
# frames to go 12217
# frames to go 12218
# frames to go 12219
# frames to go 12220
# frames to go 12221
# frames to go 12222
# frames to go 12223
# frames to go 12224
# frames to go 12225
# frames to go 12226
# frames to go 12227
# frames to go 12228
# frames to go 12229
# frames to go 12230
# frames to go 12231
# frames to go 12232
# frames to go 12233
# frames to go 12234
# frames to go 12235
# frames to go 12236
# frames to go 12237
# frames to go 12238
# frames to go 12239
# frames to go 12240
# frames to go 12241
# frames to go 12242
# frames to go 12243
# frames to go 12244
# frames to go 12245
# frames to go 12246
# frames to go 12247
# frames to go 12248
# frames to go 12249
# frames to go 12250
# frames to go 12251
# frames to go 12252
# frames to go 12253
# frames to go 12254
# frames to go 12255
# frames to go 12256
# frames to go 12257
# frames to go 12258
# frames to go 12259
# frames to go 12260
# frames to go 12261
# frames to go 12262
# frames to go 12263
# frames to go 12264
# frames to go 12265
# frames to go 12266
# frames to go 12267
# frames to go 12268
# frames to go 12269
# frames to go 12270
# frames to go 12271
# frames to go 12272
# frames to go 12273
# frames to go 12274
# frames to go 12275
# frames to go 12276
# frames to go 12277
# frames to go 12278
# frames to go 12279
# frames to go 12280
# frames to go 12281
# frames to go 12282
# frames to go 12283
# frames to go 12284
# frames to go 12285
# frames to go 12286
# frames to go 12287
# frames to go 12288
# frames to go 12289
# frames to go 12290
# frames to go 12291
# frames to go 12292
# frames to go 12293
# frames to go 12294
# frames to go 12295
# frames to go 12296
# frames to go 12297
# frames to go 12298
# frames to go 12299
# frames to go 12300
# frames to go 12301
# frames to go 12302
# frames to go 12303
# frames to go 12304
# frames to go 12305
# frames to go 12306
# frames to go 12307
# frames to go 12308
# frames to go 12309
# frames to go 12310
# frames to go 12311
# frames to go 12312
# frames to go 12313
# frames to go 12314
# frames to go 12315
# frames to go 12316
# frames to go 12317
# frames to go 12318
# frames to go 12319
# frames to go 12320
# frames to go 12321
# frames to go 12322
# frames to go 12323
# frames to go 12324
# frames to go 12325
# frames to go 12326
# frames to go 12327
# frames to go 12328
# frames to go 12329
# frames to go 12330
# frames to go 12331
# frames to go 12332
# frames to go 12333
# frames to go 12334
# frames to go 12335
# frames to go 12336
# frames to go 12337
# frames to go 12338
# frames to go 12339
# frames to go 12340
# frames to go 12341
# frames to go 12342
# frames to go 12343
# frames to go 12344
# frames to go 12345
# frames to go 12346
# frames to go 12347
# frames to go 12348
# frames to go 12349
# frames to go 12350
# frames to go 12351
# frames to go 12352
# frames to go 12353
# frames to go 12354
# frames to go 12355
# frames to go 12356
# frames to go 12357
# frames to go 12358
# frames to go 12359
# frames to go 12360
# frames to go 12361
# frames to go 12362
# frames to go 12363
# frames to go 12364
# frames to go 12365
# frames to go 12366
# frames to go 12367
# frames to go 12368
# frames to go 12369
# frames to go 12370
# frames to go 12371
# frames to go 12372
# frames to go 12373
# frames to go 12374
# frames to go 12375
# frames to go 12376
# frames to go 12377
# frames to go 12378
# frames to go 12379
# frames to go 12380
# frames to go 12381
# frames to go 12382
# frames to go 12383
# frames to go 12384
# frames to go 12385
# frames to go 12386
# frames to go 12387
# frames to go 12388
# frames to go 12389
# frames to go 12390
# frames to go 12391
# frames to go 12392
# frames to go 12393
# frames to go 12394
# frames to go 12395
# frames to go 12396
# frames to go 12397
# frames to go 12398
# frames to go 12399
# frames to go 12400
# frames to go 12401
# frames to go 12402
# frames to go 12403
# frames to go 12404
# frames to go 12405
# frames to go 12406
# frames to go 12407
# frames to go 12408
# frames to go 12409
# frames to go 12410
# frames to go 12411
# frames to go 12412
# frames to go 12413
# frames to go 12414
# frames to go 12415
# frames to go 12416
# frames to go 12417
# frames to go 12418
# frames to go 12419
# frames to go 12420
# frames to go 12421
# frames to go 12422
# frames to go 12423
# frames to go 12424
# frames to go 12425
# frames to go 12426
# frames to go 12427
# frames to go 12428
# frames to go 12429
# frames to go 12430
# frames to go 12431
# frames to go 12432
# frames to go 12433
# frames to go 12434
# frames to go 12435
# frames to go 12436
# frames to go 12437
# frames to go 12438
# frames to go 12439
# frames to go 12440
# frames to go 12441
# frames to go 12442
# frames to go 12443
# frames to go 12444
# frames to go 12445
# frames to go 12446
# frames to go 12447
# frames to go 12448
# frames to go 12449
# frames to go 12450
# frames to go 12451
# frames to go 12452
# frames to go 12453
# frames to go 12454
# frames to go 12455
# frames to go 12456
# frames to go 12457
# frames to go 12458
# frames to go 12459
# frames to go 12460
# frames to go 12461
# frames to go 12462
# frames to go 12463
# frames to go 12464
# frames to go 12465
# frames to go 12466
# frames to go 12467
# frames to go 12468
# frames to go 12469
# frames to go 12470
# frames to go 12471
# frames to go 12472
# frames to go 12473
# frames to go 12474
# frames to go 12475
# frames to go 12476
# frames to go 12477
# frames to go 12478
# frames to go 12479
# frames to go 12480
# frames to go 12481
# frames to go 12482
# frames to go 12483
# frames to go 12484
# frames to go 12485
# frames to go 12486
# frames to go 12487
# frames to go 12488
# frames to go 12489
# frames to go 12490
# frames to go 12491
# frames to go 12492
# frames to go 12493
# frames to go 12494
# frames to go 12495
# frames to go 12496
# frames to go 12497
# frames to go 12498
# frames to go 12499
# frames to go 12500
# frames to go 12501
# frames to go 12502
# frames to go 12503
# frames to go 12504
# frames to go 12505
# frames to go 12506
# frames to go 12507
# frames to go 12508
# frames to go 12509
# frames to go 12510
# frames to go 12511
# frames to go 12512
# frames to go 12513
# frames to go 12514
# frames to go 12515
# frames to go 12516
# frames to go 12517
# frames to go 12518
# frames to go 12519
# frames to go 12520
# frames to go 12521
# frames to go 12522
# frames to go 12523
# frames to go 12524
# frames to go 12525
# frames to go 12526
# frames to go 12527
# frames to go 12528
# frames to go 12529
# frames to go 12530
# frames to go 12531
# frames to go 12532
# frames to go 12533
# frames to go 12534
# frames to go 12535
# frames to go 12536
# frames to go 12537
# frames to go 12538
# frames to go 12539
# frames to go 12540
# frames to go 12541
# frames to go 12542
# frames to go 12543
# frames to go 12544
# frames to go 12545
# frames to go 12546
# frames to go 12547
# frames to go 12548
# frames to go 12549
# frames to go 12550
# frames to go 12551
# frames to go 12552
# frames to go 12553
# frames to go 12554
# frames to go 12555
# frames to go 12556
# frames to go 12557
# frames to go 12558
# frames to go 12559
# frames to go 12560
# frames to go 12561
# frames to go 12562
# frames to go 12563
# frames to go 12564
# frames to go 12565
# frames to go 12566
# frames to go 12567
# frames to go 12568
# frames to go 12569
# frames to go 12570
# frames to go 12571
# frames to go 12572
# frames to go 12573
# frames to go 12574
# frames to go 12575
# frames to go 12576
# frames to go 12577
# frames to go 12578
# frames to go 12579
# frames to go 12580
# frames to go 12581
# frames to go 12582
# frames to go 12583
# frames to go 12584
# frames to go 12585
# frames to go 12586
# frames to go 12587
# frames to go 12588
# frames to go 12589
# frames to go 12590
# frames to go 12591
# frames to go 12592
# frames to go 12593
# frames to go 12594
# frames to go 12595
# frames to go 12596
# frames to go 12597
# frames to go 12598
# frames to go 12599
# frames to go 12600
# frames to go 12601
# frames to go 12602
# frames to go 12603
# frames to go 12604
# frames to go 12605
# frames to go 12606
# frames to go 12607
# frames to go 12608
# frames to go 12609
# frames to go 12610
# frames to go 12611
# frames to go 12612
# frames to go 12613
# frames to go 12614
# frames to go 12615
# frames to go 12616
# frames to go 12617
# frames to go 12618
# frames to go 12619
# frames to go 12620
# frames to go 12621
# frames to go 12622
# frames to go 12623
# frames to go 12624
# frames to go 12625
# frames to go 12626
# frames to go 12627
# frames to go 12628
# frames to go 12629
# frames to go 12630
# frames to go 12631
# frames to go 12632
# frames to go 12633
# frames to go 12634
# frames to go 12635
# frames to go 12636
# frames to go 12637
# frames to go 12638
# frames to go 12639
# frames to go 12640
# frames to go 12641
# frames to go 12642
# frames to go 12643
# frames to go 12644
# frames to go 12645
# frames to go 12646
# frames to go 12647
# frames to go 12648
# frames to go 12649
# frames to go 12650
# frames to go 12651
# frames to go 12652
# frames to go 12653
# frames to go 12654
# frames to go 12655
# frames to go 12656
# frames to go 12657
# frames to go 12658
# frames to go 12659
# frames to go 12660
# frames to go 12661
# frames to go 12662
# frames to go 12663
# frames to go 12664
# frames to go 12665
# frames to go 12666
# frames to go 12667
# frames to go 12668
# frames to go 12669
# frames to go 12670
# frames to go 12671
# frames to go 12672
# frames to go 12673
# frames to go 12674
# frames to go 12675
# frames to go 12676
# frames to go 12677
# frames to go 12678
# frames to go 12679
# frames to go 12680
# frames to go 12681
# frames to go 12682
# frames to go 12683
# frames to go 12684
# frames to go 12685
# frames to go 12686
# frames to go 12687
# frames to go 12688
# frames to go 12689
# frames to go 12690
# frames to go 12691
# frames to go 12692
# frames to go 12693
# frames to go 12694
# frames to go 12695
# frames to go 12696
# frames to go 12697
# frames to go 12698
# frames to go 12699
# frames to go 12700
# frames to go 12701
# frames to go 12702
# frames to go 12703
# frames to go 12704
# frames to go 12705
# frames to go 12706
# frames to go 12707
# frames to go 12708
# frames to go 12709
# frames to go 12710
# frames to go 12711
# frames to go 12712
# frames to go 12713
# frames to go 12714
# frames to go 12715
# frames to go 12716
# frames to go 12717
# frames to go 12718
# frames to go 12719
# frames to go 12720
# frames to go 12721
# frames to go 12722
# frames to go 12723
# frames to go 12724
# frames to go 12725
# frames to go 12726
# frames to go 12727
# frames to go 12728
# frames to go 12729
# frames to go 12730
# frames to go 12731
# frames to go 12732
# frames to go 12733
# frames to go 12734
# frames to go 12735
# frames to go 12736
# frames to go 12737
# frames to go 12738
# frames to go 12739
# frames to go 12740
# frames to go 12741
# frames to go 12742
# frames to go 12743
# frames to go 12744
# frames to go 12745
# frames to go 12746
# frames to go 12747
# frames to go 12748
# frames to go 12749
# frames to go 12750
# frames to go 12751
# frames to go 12752
# frames to go 12753
# frames to go 12754
# frames to go 12755
# frames to go 12756
# frames to go 12757
# frames to go 12758
# frames to go 12759
# frames to go 12760
# frames to go 12761
# frames to go 12762
# frames to go 12763
# frames to go 12764
# frames to go 12765
# frames to go 12766
# frames to go 12767
# frames to go 12768
# frames to go 12769
# frames to go 12770
# frames to go 12771
# frames to go 12772
# frames to go 12773
# frames to go 12774
# frames to go 12775
# frames to go 12776
# frames to go 12777
# frames to go 12778
# frames to go 12779
# frames to go 12780
# frames to go 12781
# frames to go 12782
# frames to go 12783
# frames to go 12784
# frames to go 12785
# frames to go 12786
# frames to go 12787
# frames to go 12788
# frames to go 12789
# frames to go 12790
# frames to go 12791
# frames to go 12792
# frames to go 12793
# frames to go 12794
# frames to go 12795
# frames to go 12796
# frames to go 12797
# frames to go 12798
# frames to go 12799
# frames to go 12800
# frames to go 12801
# frames to go 12802
# frames to go 12803
# frames to go 12804
# frames to go 12805
# frames to go 12806
# frames to go 12807
# frames to go 12808
# frames to go 12809
# frames to go 12810
# frames to go 12811
# frames to go 12812
# frames to go 12813
# frames to go 12814
# frames to go 12815
# frames to go 12816
# frames to go 12817
# frames to go 12818
# frames to go 12819
# frames to go 12820
# frames to go 12821
# frames to go 12822
# frames to go 12823
# frames to go 12824
# frames to go 12825
# frames to go 12826
# frames to go 12827
# frames to go 12828
# frames to go 12829
# frames to go 12830
# frames to go 12831
# frames to go 12832
# frames to go 12833
# frames to go 12834
# frames to go 12835
# frames to go 12836
# frames to go 12837
# frames to go 12838
# frames to go 12839
# frames to go 12840
# frames to go 12841
# frames to go 12842
# frames to go 12843
# frames to go 12844
# frames to go 12845
# frames to go 12846
# frames to go 12847
# frames to go 12848
# frames to go 12849
# frames to go 12850
# frames to go 12851
# frames to go 12852
# frames to go 12853
# frames to go 12854
# frames to go 12855
# frames to go 12856
# frames to go 12857
# frames to go 12858
# frames to go 12859
# frames to go 12860
# frames to go 12861
# frames to go 12862
# frames to go 12863
# frames to go 12864
# frames to go 12865
# frames to go 12866
# frames to go 12867
# frames to go 12868
# frames to go 12869
# frames to go 12870
# frames to go 12871
# frames to go 12872
# frames to go 12873
# frames to go 12874
# frames to go 12875
# frames to go 12876
# frames to go 12877
# frames to go 12878
# frames to go 12879
# frames to go 12880
# frames to go 12881
# frames to go 12882
# frames to go 12883
# frames to go 12884
# frames to go 12885
# frames to go 12886
# frames to go 12887
# frames to go 12888
# frames to go 12889
# frames to go 12890
# frames to go 12891
# frames to go 12892
# frames to go 12893
# frames to go 12894
# frames to go 12895
# frames to go 12896
# frames to go 12897
# frames to go 12898
# frames to go 12899
# frames to go 12900
# frames to go 12901
# frames to go 12902
# frames to go 12903
# frames to go 12904
# frames to go 12905
# frames to go 12906
# frames to go 12907
# frames to go 12908
# frames to go 12909
# frames to go 12910
# frames to go 12911
# frames to go 12912
# frames to go 12913
# frames to go 12914
# frames to go 12915
# frames to go 12916
# frames to go 12917
# frames to go 12918
# frames to go 12919
# frames to go 12920
# frames to go 12921
# frames to go 12922
# frames to go 12923
# frames to go 12924
# frames to go 12925
# frames to go 12926
# frames to go 12927
# frames to go 12928
# frames to go 12929
# frames to go 12930
# frames to go 12931
# frames to go 12932
# frames to go 12933
# frames to go 12934
# frames to go 12935
# frames to go 12936
# frames to go 12937
# frames to go 12938
# frames to go 12939
# frames to go 12940
# frames to go 12941
# frames to go 12942
# frames to go 12943
# frames to go 12944
# frames to go 12945
# frames to go 12946
# frames to go 12947
# frames to go 12948
# frames to go 12949
# frames to go 12950
# frames to go 12951
# frames to go 12952
# frames to go 12953
# frames to go 12954
# frames to go 12955
# frames to go 12956
# frames to go 12957
# frames to go 12958
# frames to go 12959
# frames to go 12960
# frames to go 12961
# frames to go 12962
# frames to go 12963
# frames to go 12964
# frames to go 12965
# frames to go 12966
# frames to go 12967
# frames to go 12968
# frames to go 12969
# frames to go 12970
# frames to go 12971
# frames to go 12972
# frames to go 12973
# frames to go 12974
# frames to go 12975
# frames to go 12976
# frames to go 12977
# frames to go 12978
# frames to go 12979
# frames to go 12980
# frames to go 12981
# frames to go 12982
# frames to go 12983
# frames to go 12984
# frames to go 12985
# frames to go 12986
# frames to go 12987
# frames to go 12988
# frames to go 12989
# frames to go 12990
# frames to go 12991
# frames to go 12992
# frames to go 12993
# frames to go 12994
# frames to go 12995
# frames to go 12996
# frames to go 12997
# frames to go 12998
# frames to go 12999
# frames to go 13000
# frames to go 13001
# frames to go 13002
# frames to go 13003
# frames to go 13004
# frames to go 13005
# frames to go 13006
# frames to go 13007
# frames to go 13008
# frames to go 13009
# frames to go 13010
# frames to go 13011
# frames to go 13012
# frames to go 13013
# frames to go 13014
# frames to go 13015
# frames to go 13016
# frames to go 13017
# frames to go 13018
# frames to go 13019
# frames to go 13020
# frames to go 13021
# frames to go 13022
# frames to go 13023
# frames to go 13024
# frames to go 13025
# frames to go 13026
# frames to go 13027
# frames to go 13028
# frames to go 13029
# frames to go 13030
# frames to go 13031
# frames to go 13032
# frames to go 13033
# frames to go 13034
# frames to go 13035
# frames to go 13036
# frames to go 13037
# frames to go 13038
# frames to go 13039
# frames to go 13040
# frames to go 13041
# frames to go 13042
# frames to go 13043
# frames to go 13044
# frames to go 13045
# frames to go 13046
# frames to go 13047
# frames to go 13048
# frames to go 13049
# frames to go 13050
# frames to go 13051
# frames to go 13052
# frames to go 13053
# frames to go 13054
# frames to go 13055
# frames to go 13056
# frames to go 13057
# frames to go 13058
# frames to go 13059
# frames to go 13060
# frames to go 13061
# frames to go 13062
# frames to go 13063
# frames to go 13064
# frames to go 13065
# frames to go 13066
# frames to go 13067
# frames to go 13068
# frames to go 13069
# frames to go 13070
# frames to go 13071
# frames to go 13072
# frames to go 13073
# frames to go 13074
# frames to go 13075
# frames to go 13076
# frames to go 13077
# frames to go 13078
# frames to go 13079
# frames to go 13080
# frames to go 13081
# frames to go 13082
# frames to go 13083
# frames to go 13084
# frames to go 13085
# frames to go 13086
# frames to go 13087
# frames to go 13088
# frames to go 13089
# frames to go 13090
# frames to go 13091
# frames to go 13092
# frames to go 13093
# frames to go 13094
# frames to go 13095
# frames to go 13096
# frames to go 13097
# frames to go 13098
# frames to go 13099
# frames to go 13100
# frames to go 13101
# frames to go 13102
# frames to go 13103
# frames to go 13104
# frames to go 13105
# frames to go 13106
# frames to go 13107
# frames to go 13108
# frames to go 13109
# frames to go 13110
# frames to go 13111
# frames to go 13112
# frames to go 13113
# frames to go 13114
# frames to go 13115
# frames to go 13116
# frames to go 13117
# frames to go 13118
# frames to go 13119
# frames to go 13120
# frames to go 13121
# frames to go 13122
# frames to go 13123
# frames to go 13124
# frames to go 13125
# frames to go 13126
# frames to go 13127
# frames to go 13128
# frames to go 13129
# frames to go 13130
# frames to go 13131
# frames to go 13132
# frames to go 13133
# frames to go 13134
# frames to go 13135
# frames to go 13136
# frames to go 13137
# frames to go 13138
# frames to go 13139
# frames to go 13140
# frames to go 13141
# frames to go 13142
# frames to go 13143
# frames to go 13144
# frames to go 13145
# frames to go 13146
# frames to go 13147
# frames to go 13148
# frames to go 13149
# frames to go 13150
# frames to go 13151
# frames to go 13152
# frames to go 13153
# frames to go 13154
# frames to go 13155
# frames to go 13156
# frames to go 13157
# frames to go 13158
# frames to go 13159
# frames to go 13160
# frames to go 13161
# frames to go 13162
# frames to go 13163
# frames to go 13164
# frames to go 13165
# frames to go 13166
# frames to go 13167
# frames to go 13168
# frames to go 13169
# frames to go 13170
# frames to go 13171
# frames to go 13172
# frames to go 13173
# frames to go 13174
# frames to go 13175
# frames to go 13176
# frames to go 13177
# frames to go 13178
# frames to go 13179
# frames to go 13180
# frames to go 13181
# frames to go 13182
# frames to go 13183
# frames to go 13184
# frames to go 13185
# frames to go 13186
# frames to go 13187
# frames to go 13188
# frames to go 13189
# frames to go 13190
# frames to go 13191
# frames to go 13192
# frames to go 13193
# frames to go 13194
# frames to go 13195
# frames to go 13196
# frames to go 13197
# frames to go 13198
# frames to go 13199
# frames to go 13200
# frames to go 13201
# frames to go 13202
# frames to go 13203
# frames to go 13204
# frames to go 13205
# frames to go 13206
# frames to go 13207
# frames to go 13208
# frames to go 13209
# frames to go 13210
# frames to go 13211
# frames to go 13212
# frames to go 13213
# frames to go 13214
# frames to go 13215
# frames to go 13216
# frames to go 13217
# frames to go 13218
# frames to go 13219
# frames to go 13220
# frames to go 13221
# frames to go 13222
# frames to go 13223
# frames to go 13224
# frames to go 13225
# frames to go 13226
# frames to go 13227
# frames to go 13228
# frames to go 13229
# frames to go 13230
# frames to go 13231
# frames to go 13232
# frames to go 13233
# frames to go 13234
# frames to go 13235
# frames to go 13236
# frames to go 13237
# frames to go 13238
# frames to go 13239
# frames to go 13240
# frames to go 13241
# frames to go 13242
# frames to go 13243
# frames to go 13244
# frames to go 13245
# frames to go 13246
# frames to go 13247
# frames to go 13248
# frames to go 13249
# frames to go 13250
# frames to go 13251
# frames to go 13252
# frames to go 13253
# frames to go 13254
# frames to go 13255
# frames to go 13256
# frames to go 13257
# frames to go 13258
# frames to go 13259
# frames to go 13260
# frames to go 13261
# frames to go 13262
# frames to go 13263
# frames to go 13264
# frames to go 13265
# frames to go 13266
# frames to go 13267
# frames to go 13268
# frames to go 13269
# frames to go 13270
# frames to go 13271
# frames to go 13272
# frames to go 13273
# frames to go 13274
# frames to go 13275
# frames to go 13276
# frames to go 13277
# frames to go 13278
# frames to go 13279
# frames to go 13280
# frames to go 13281
# frames to go 13282
# frames to go 13283
# frames to go 13284
# frames to go 13285
# frames to go 13286
# frames to go 13287
# frames to go 13288
# frames to go 13289
# frames to go 13290
# frames to go 13291
# frames to go 13292
# frames to go 13293
# frames to go 13294
# frames to go 13295
# frames to go 13296
# frames to go 13297
# frames to go 13298
# frames to go 13299
# frames to go 13300
# frames to go 13301
# frames to go 13302
# frames to go 13303
# frames to go 13304
# frames to go 13305
# frames to go 13306
# frames to go 13307
# frames to go 13308
# frames to go 13309
# frames to go 13310
# frames to go 13311
# frames to go 13312
# frames to go 13313
# frames to go 13314
# frames to go 13315
# frames to go 13316
# frames to go 13317
# frames to go 13318
# frames to go 13319
# frames to go 13320
# frames to go 13321
# frames to go 13322
# frames to go 13323
# frames to go 13324
# frames to go 13325
# frames to go 13326
# frames to go 13327
# frames to go 13328
# frames to go 13329
# frames to go 13330
# frames to go 13331
# frames to go 13332
# frames to go 13333
# frames to go 13334
# frames to go 13335
# frames to go 13336
# frames to go 13337
# frames to go 13338
# frames to go 13339
# frames to go 13340
# frames to go 13341
# frames to go 13342
# frames to go 13343
# frames to go 13344
# frames to go 13345
# frames to go 13346
# frames to go 13347
# frames to go 13348
# frames to go 13349
# frames to go 13350
# frames to go 13351
# frames to go 13352
# frames to go 13353
# frames to go 13354
# frames to go 13355
# frames to go 13356
# frames to go 13357
# frames to go 13358
# frames to go 13359
# frames to go 13360
# frames to go 13361
# frames to go 13362
# frames to go 13363
# frames to go 13364
# frames to go 13365
# frames to go 13366
# frames to go 13367
# frames to go 13368
# frames to go 13369
# frames to go 13370
# frames to go 13371
# frames to go 13372
# frames to go 13373
# frames to go 13374
# frames to go 13375
# frames to go 13376
# frames to go 13377
# frames to go 13378
# frames to go 13379
# frames to go 13380
# frames to go 13381
# frames to go 13382
# frames to go 13383
# frames to go 13384
# frames to go 13385
# frames to go 13386
# frames to go 13387
# frames to go 13388
# frames to go 13389
# frames to go 13390
# frames to go 13391
# frames to go 13392
# frames to go 13393
# frames to go 13394
# frames to go 13395
# frames to go 13396
# frames to go 13397
# frames to go 13398
# frames to go 13399
# frames to go 13400
# frames to go 13401
# frames to go 13402
# frames to go 13403
# frames to go 13404
# frames to go 13405
# frames to go 13406
# frames to go 13407
# frames to go 13408
# frames to go 13409
# frames to go 13410
# frames to go 13411
# frames to go 13412
# frames to go 13413
# frames to go 13414
# frames to go 13415
# frames to go 13416
# frames to go 13417
# frames to go 13418
# frames to go 13419
# frames to go 13420
# frames to go 13421
# frames to go 13422
# frames to go 13423
# frames to go 13424
# frames to go 13425
# frames to go 13426
# frames to go 13427
# frames to go 13428
# frames to go 13429
# frames to go 13430
# frames to go 13431
# frames to go 13432
# frames to go 13433
# frames to go 13434
# frames to go 13435
# frames to go 13436
# frames to go 13437
# frames to go 13438
# frames to go 13439
# frames to go 13440
# frames to go 13441
# frames to go 13442
# frames to go 13443
# frames to go 13444
# frames to go 13445
# frames to go 13446
# frames to go 13447
# frames to go 13448
# frames to go 13449
# frames to go 13450
# frames to go 13451
# frames to go 13452
# frames to go 13453
# frames to go 13454
# frames to go 13455
# frames to go 13456
# frames to go 13457
# frames to go 13458
# frames to go 13459
# frames to go 13460
# frames to go 13461
# frames to go 13462
# frames to go 13463
# frames to go 13464
# frames to go 13465
# frames to go 13466
# frames to go 13467
# frames to go 13468
# frames to go 13469
# frames to go 13470
# frames to go 13471
# frames to go 13472
# frames to go 13473
# frames to go 13474
# frames to go 13475
# frames to go 13476
# frames to go 13477
# frames to go 13478
# frames to go 13479
# frames to go 13480
# frames to go 13481
# frames to go 13482
# frames to go 13483
# frames to go 13484
# frames to go 13485
# frames to go 13486
# frames to go 13487
# frames to go 13488
# frames to go 13489
# frames to go 13490
# frames to go 13491
# frames to go 13492
# frames to go 13493
# frames to go 13494
# frames to go 13495
# frames to go 13496
# frames to go 13497
# frames to go 13498
# frames to go 13499
# frames to go 13500
# frames to go 13501
# frames to go 13502
# frames to go 13503
# frames to go 13504
# frames to go 13505
# frames to go 13506
# frames to go 13507
# frames to go 13508
# frames to go 13509
# frames to go 13510
# frames to go 13511
# frames to go 13512
# frames to go 13513
# frames to go 13514
# frames to go 13515
# frames to go 13516
# frames to go 13517
# frames to go 13518
# frames to go 13519
# frames to go 13520
# frames to go 13521
# frames to go 13522
# frames to go 13523
# frames to go 13524
# frames to go 13525
# frames to go 13526
# frames to go 13527
# frames to go 13528
# frames to go 13529
# frames to go 13530
# frames to go 13531
# frames to go 13532
# frames to go 13533
# frames to go 13534
# frames to go 13535
# frames to go 13536
# frames to go 13537
# frames to go 13538
# frames to go 13539
# frames to go 13540
# frames to go 13541
# frames to go 13542
# frames to go 13543
# frames to go 13544
# frames to go 13545
# frames to go 13546
# frames to go 13547
# frames to go 13548
# frames to go 13549
# frames to go 13550
# frames to go 13551
# frames to go 13552
# frames to go 13553
# frames to go 13554
# frames to go 13555
# frames to go 13556
# frames to go 13557
# frames to go 13558
# frames to go 13559
# frames to go 13560
# frames to go 13561
# frames to go 13562
# frames to go 13563
# frames to go 13564
# frames to go 13565
# frames to go 13566
# frames to go 13567
# frames to go 13568
# frames to go 13569
# frames to go 13570
# frames to go 13571
# frames to go 13572
# frames to go 13573
# frames to go 13574
# frames to go 13575
# frames to go 13576
# frames to go 13577
# frames to go 13578
# frames to go 13579
# frames to go 13580
# frames to go 13581
# frames to go 13582
# frames to go 13583
# frames to go 13584
# frames to go 13585
# frames to go 13586
# frames to go 13587
# frames to go 13588
# frames to go 13589
# frames to go 13590
# frames to go 13591
# frames to go 13592
# frames to go 13593
# frames to go 13594
# frames to go 13595
# frames to go 13596
# frames to go 13597
# frames to go 13598
# frames to go 13599
# frames to go 13600
# frames to go 13601
# frames to go 13602
# frames to go 13603

# %% [markdown]
# ## Set the style

# %%
# Pick a style
styles = "hosoda" #@param ["shinkai", "hayao", "hosoda", "paprika"]

# %% [markdown]
# ## Set Dimensions

# %%
# generate the movie sequence
searchedfiles = glob.glob(img_in_folder+'/*.jpg')
files = sorted( searchedfiles, key = lambda file: os.path.getctime(file))

files_sorted=[]
combined_sorted=[]
# fill the frame list before the processed image even beeing there
for i in files:
  # split off the filename
  isa = i.split('/')
  # append it with the processed folder path and file definition
  combined_sorted.append("file '"+root+"processed_"+video_name +"_frames/comparison/"+isa[len(isa)-1]+"'\n")
  files_sorted.append("file '"+root+"processed_"+video_name +"_frames/"+styles+"/"+isa[len(isa)-1]+"'\n")
print(combined_sorted)
print(files_sorted)

# for file in files check height
for f in files:
  img = cv2.imread(f)
  h,w,c = img.shape
  # Resize if needed
  if h > max_size:
    img_resized = resize(img,window_height = max_size)
    rh,rw,rc = img_resized.shape
    cv2.imwrite(f,img_resized)
# Out:
# ["file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image1.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image2.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image3.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image4.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image5.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image6.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image7.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image8.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image9.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image10.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image11.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image12.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image13.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image14.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image15.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image16.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image17.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image18.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image19.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image20.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image21.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image22.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image23.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image24.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image25.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image26.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image27.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image28.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image29.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image30.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image31.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image32.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image33.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image34.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image35.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image36.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image37.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image38.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image39.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image40.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image41.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image42.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image43.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image44.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image45.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/comparison/image46.jpg'\n", "file  ...
# ["file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image1.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image2.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image3.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image4.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image5.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image6.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image7.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image8.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image9.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image10.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image11.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image12.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image13.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image14.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image15.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image16.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image17.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image18.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image19.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image20.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image21.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image22.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image23.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image24.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image25.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image26.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image27.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image28.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image29.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image30.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image31.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image32.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image33.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image34.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image35.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image36.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image37.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image38.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image39.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image40.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image41.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image42.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image43.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image44.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image45.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image46.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/paprika/image47.jpg'\n", "file '/content/Cartoonizer/processed_techno_dark_2_frames/p ...

# %% [markdown]
# ## Run the Cartoonizer

# %%
# !ls
# os.chdir('CartoonGan-tensorflow')
# run the Cartoonizerrrrrrrrrrrrrrrrrrrr
# !python cartoonize.py \
  --comparison_view horizontal \
  --keep_original_size \
  --batch_size 2 \
  --styles '{styles}' \
  --input_dir '{img_in_folder}' \
  --output_dir '{img_out_folder}'
# Out:
# [2019-08-27 08:27:35] [Cartoonizer] [INFO] Transformed images will be saved to `/content/Cartoonizer/processed_techno_dark_2_frames` folder.
# [2019-08-27 08:27:37] [Cartoonizer] [INFO] Cartoonizing images using paprika style...
# [2019-08-27 08:27:37] [Cartoonizer] [INFO] Preparing to transform 2473 images from `/content/Cartoonizer/techno_dark_2_frames` directory...
# Transforming: 100% 2473/2473 [15:41<00:00,  2.65it/s, File=image2005.jpg]
# [2019-08-27 08:43:18] [Cartoonizer] [INFO] Total processing time: 0:15:43.290025

# %% [markdown]
# ## Forming the new video

# %%
with open(root+'/paths.txt', 'w') as in_files:
  in_files.writelines(fn for fn in files_sorted)
with open(root+'/compare_paths.txt', 'w') as in_files:
  in_files.writelines(fn for fn in combined_sorted)
  
# !ffmpeg -y -r 1/{framerate} -f concat -safe 0 -i  '{root}'"paths.txt" -c:v libx264 -vf "fps=1/"{framerate}",format=yuv420p" '{root}'"processed_"{video_name}".mp4"
# !ffmpeg -i '{root}'"processed_"'{video_name}'".mp4" -i '{audio_file}' -shortest '{root}'"final_processed_"'{video_name}'"_vid.mp4"

# !ffmpeg -y -r 1/{framerate} -f concat -safe 0 -i  '{root}'"compare_paths.txt" -c:v libx264 -vf "fps=1/"{framerate}",format=yuv420p" '{root}'"processed_compare_"{video_name}".mp4"
# !ffmpeg -i '{root}'"processed_compare_"'{video_name}'".mp4" -i '{audio_file}' -shortest '{root}'"final_processed_compare_"'{video_name}'"_vid.mp4"
# Out:
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, concat, from '/content/Cartoonizer/paths.txt':
#   Duration: N/A, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 640x360 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55d295820000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x55d2956aa800] using SAR=1/1
# [libx264 @ 0x55d2956aa800] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55d2956aa800] profile High, level 2.2
# [libx264 @ 0x55d2956aa800] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/Cartoonizer/processed_techno_dark_2.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 640x360 [SAR 1:1 DAR 16:9], q=-1--1, 6.67 fps, 10240 tbn, 6.67 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# [mjpeg @ 0x55d2956aad00] EOI missing, emulating
#     Last message repeated 1 times
# [mjpeg @ 0x55d2956aad00] EOI missing, emulating
#     Last message repeated 2 times
# [mjpeg @ 0x55d2956aad00] EOI missing, emulating
#     Last message repeated 1 times
# [mjpeg @ 0x55d2956aad00] EOI missing, emulating
#     Last message repeated 1 times
# [mjpeg @ 0x55d2956aad00] EOI missing, emulating
#     Last message repeated 9 times
# [mjpeg @ 0x55d2956aad00] EOI missing, emulating
#     Last message repeated 16 times
# [mjpeg @ 0x55d2956aad00] EOI missing, emulating
#     Last message repeated 11 times
# frame= 2473 fps= 29 q=-1.0 Lsize=   37604kB time=00:06:10.50 bitrate= 831.4kbits/s speed=4.35x
# video:37576kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.075049%
# [libx264 @ 0x55d2956aa800] frame I:237   Avg QP:18.14  size: 22633
# [libx264 @ 0x55d2956aa800] frame P:841   Avg QP:21.55  size: 16165
# [libx264 @ 0x55d2956aa800] frame B:1395  Avg QP:22.24  size: 13991
# [libx264 @ 0x55d2956aa800] consecutive B-frames: 19.5%  9.9% 17.8% 52.7%
# [libx264 @ 0x55d2956aa800] mb I  I16..4:  6.4% 90.1%  3.5%
# [libx264 @ 0x55d2956aa800] mb P  I16..4:  6.8% 69.6%  5.8%  P16..4:  5.7%  6.7%  2.7%  0.0%  0.0%    skip: 2.8%
# [libx264 @ 0x55d2956aa800] mb B  I16..4:  5.2% 42.0%  5.1%  B16..8: 15.2% 17.5%  5.1%  direct: 5.2%  skip: 4.7%  L0:41.7% L1:34.2% BI:24.1%
# [libx264 @ 0x55d2956aa800] 8x8 transform intra:83.6% inter:73.6%
# [libx264 @ 0x55d2956aa800] coded y,uvDC,uvAC intra: 69.2% 90.0% 50.0% inter: 58.6% 76.3% 13.6%
# [libx264 @ 0x55d2956aa800] i16 v,h,dc,p: 35% 34% 13% 19%
# [libx264 @ 0x55d2956aa800] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 30% 22%  3%  3%  4%  4%  3%  4%
# [libx264 @ 0x55d2956aa800] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 20% 16%  5%  5%  6%  6%  5%  5%
# [libx264 @ 0x55d2956aa800] i8c dc,h,v,p: 38% 28% 24%  9%
# [libx264 @ 0x55d2956aa800] Weighted P-Frames: Y:26.4% UV:25.3%
# [libx264 @ 0x55d2956aa800] ref P L0: 59.4% 15.3% 14.3%  8.9%  2.2%
# [libx264 @ 0x55d2956aa800] ref B L0: 85.4% 12.1%  2.5%
# [libx264 @ 0x55d2956aa800] ref B L1: 95.0%  5.0%
# [libx264 @ 0x55d2956aa800] kb/s:829.80
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/Cartoonizer/processed_techno_dark_2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:06:10.95, start: 0.000000, bitrate: 830 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 640x360 [SAR 1:1 DAR 16:9], 829 kb/s, 6.67 fps, 6.67 tbr, 10240 tbn, 13.33 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Input #1, mp3, from '/content/Cartoonizer/techno_dark_2.mp3':
#   Metadata:
#     encoder         : Lavf57.72.101
#   Duration: 00:06:10.99, start: 0.025057, bitrate: 128 kb/s
#     Stream #1:0: Audio: mp3, 44100 Hz, stereo, s16p, 128 kb/s
#     Metadata:
#       encoder         : Lavc57.96
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (mp3 (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55cea2b2c800] using SAR=1/1
# [libx264 @ 0x55cea2b2c800] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55cea2b2c800] profile High, level 2.2
# [libx264 @ 0x55cea2b2c800] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/Cartoonizer/final_processed_techno_dark_2_vid.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p(progressive), 640x360 [SAR 1:1 DAR 16:9], q=-1--1, 6.67 fps, 10240 tbn, 6.67 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s
#     Metadata:
#       encoder         : Lavc57.107.100 aac
# frame= 2473 fps= 25 q=-1.0 Lsize=   41490kB time=00:06:10.96 bitrate= 916.2kbits/s speed=3.81x
# video:35318kB audio:6035kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.330493%
# [libx264 @ 0x55cea2b2c800] frame I:237   Avg QP:18.09  size: 22143
# [libx264 @ 0x55cea2b2c800] frame P:846   Avg QP:21.49  size: 15327
# [libx264 @ 0x55cea2b2c800] frame B:1390  Avg QP:22.16  size: 12914
# [libx264 @ 0x55cea2b2c800] consecutive B-frames: 19.5% 10.9% 17.3% 52.2%
# [libx264 @ 0x55cea2b2c800] mb I  I16..4:  7.4% 88.2%  4.4%
# [libx264 @ 0x55cea2b2c800] mb P  I16..4:  8.2% 64.7%  7.0%  P16..4:  7.4%  7.2%  2.8%  0.0%  0.0%    skip: 2.7%
# [libx264 @ 0x55cea2b2c800] mb B  I16..4:  5.7% 34.3%  5.7%  B16..8: 19.5% 18.5%  5.0%  direct: 6.0%  skip: 5.2%  L0:43.7% L1:36.6% BI:19.7%
# [libx264 @ 0x55cea2b2c800] 8x8 transform intra:79.6% inter:73.7%
# [libx264 @ 0x55cea2b2c800] coded y,uvDC,uvAC intra: 65.1% 89.9% 50.8% inter: 53.5% 73.2% 8.0%
# [libx264 @ 0x55cea2b2c800] i16 v,h,dc,p: 31% 33% 12% 24%
# [libx264 @ 0x55cea2b2c800] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 29% 19%  3%  4%  4%  5%  4%  5%
# [libx264 @ 0x55cea2b2c800] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 21% 17%  5%  5%  6%  5%  5%  5%
# [libx264 @ 0x55cea2b2c800] i8c dc,h,v,p: 38% 28% 24% 10%
# [libx264 @ 0x55cea2b2c800] Weighted P-Frames: Y:25.2% UV:24.3%
# [libx264 @ 0x55cea2b2c800] ref P L0: 60.7% 15.0% 14.1%  8.3%  1.9%
# [libx264 @ 0x55cea2b2c800] ref B L0: 85.9% 11.7%  2.4%
# [libx264 @ 0x55cea2b2c800] ref B L1: 95.4%  4.6%
# [libx264 @ 0x55cea2b2c800] kb/s:779.95
# [aac @ 0x55cea2b2d700] Qavg: 509.971
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, concat, from '/content/Cartoonizer/compare_paths.txt':
#   Duration: N/A, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x360 [SAR 1:1 DAR 32:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x564467300000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x56446712a800] using SAR=1/1
# [libx264 @ 0x56446712a800] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56446712a800] profile High, level 3.1
# [libx264 @ 0x56446712a800] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/Cartoonizer/processed_compare_techno_dark_2.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x360 [SAR 1:1 DAR 32:9], q=-1--1, 6.67 fps, 10240 tbn, 6.67 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# [mjpeg @ 0x564467128a00] EOI missing, emulating
# [mjpeg @ 0x564467128a00] EOI missing, emulating
# frame= 2473 fps= 15 q=-1.0 Lsize=   68013kB time=00:06:10.50 bitrate=1503.8kbits/s speed=2.27x
# video:67984kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.042762%
# [libx264 @ 0x56446712a800] frame I:222   Avg QP:18.70  size: 42992
# [libx264 @ 0x56446712a800] frame P:795   Avg QP:21.71  size: 30552
# [libx264 @ 0x56446712a800] frame B:1456  Avg QP:22.35  size: 24576
# [libx264 @ 0x56446712a800] consecutive B-frames: 17.0%  7.9% 16.9% 58.2%
# [libx264 @ 0x56446712a800] mb I  I16..4:  5.5% 88.8%  5.7%
# [libx264 @ 0x56446712a800] mb P  I16..4:  6.3% 68.1%  6.4%  P16..4:  6.8%  7.0%  2.6%  0.0%  0.0%    skip: 2.7%
# [libx264 @ 0x56446712a800] mb B  I16..4:  4.3% 36.2%  5.0%  B16..8: 19.1% 18.0%  5.1%  direct: 5.9%  skip: 6.4%  L0:44.2% L1:32.7% BI:23.1%
# [libx264 @ 0x56446712a800] 8x8 transform intra:82.8% inter:72.3%
# [libx264 @ 0x56446712a800] coded y,uvDC,uvAC intra: 74.6% 90.7% 50.7% inter: 52.3% 69.9% 11.2%
# [libx264 @ 0x56446712a800] i16 v,h,dc,p: 33% 36% 10% 21%
# [libx264 @ 0x56446712a800] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 34% 18%  3%  3%  4%  5%  4%  5%
# [libx264 @ 0x56446712a800] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 22% 13%  5%  6%  6%  6%  6%  5%
# [libx264 @ 0x56446712a800] i8c dc,h,v,p: 37% 30% 22% 11%
# [libx264 @ 0x56446712a800] Weighted P-Frames: Y:3.1% UV:2.8%
# [libx264 @ 0x56446712a800] ref P L0: 65.7% 13.5% 13.2%  7.3%  0.3%
# [libx264 @ 0x56446712a800] ref B L0: 90.3%  7.9%  1.8%
# [libx264 @ 0x56446712a800] ref B L1: 96.5%  3.5%
# [libx264 @ 0x56446712a800] kb/s:1501.33
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/Cartoonizer/processed_compare_techno_dark_2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:06:10.95, start: 0.000000, bitrate: 1501 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x360 [SAR 1:1 DAR 32:9], 1501 kb/s, 6.67 fps, 6.67 tbr, 10240 tbn, 13.33 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Input #1, mp3, from '/content/Cartoonizer/techno_dark_2.mp3':
#   Metadata:
#     encoder         : Lavf57.72.101
#   Duration: 00:06:10.99, start: 0.025057, bitrate: 128 kb/s
#     Stream #1:0: Audio: mp3, 44100 Hz, stereo, s16p, 128 kb/s
#     Metadata:
#       encoder         : Lavc57.96
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (mp3 (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55d328916800] using SAR=1/1
# [libx264 @ 0x55d328916800] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55d328916800] profile High, level 3.1
# [libx264 @ 0x55d328916800] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/Cartoonizer/final_processed_compare_techno_dark_2_vid.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p(progressive), 1280x360 [SAR 1:1 DAR 32:9], q=-1--1, 6.67 fps, 10240 tbn, 6.67 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s
#     Metadata:
#       encoder         : Lavc57.107.100 aac

# %% [markdown]
# ## View results

# %%
folders = [f for f in glob.glob(img_out_folder + "**/*", recursive=True)]
for d in folders:
  # !tree '{d}'
  files = [f for f in glob.glob( d + "**/*.jpg", recursive=True )]
  for f in files:
      display(Image(f))

# %%
import moviepy
from moviepy.editor import VideoFileClip, clips_array, vfx
print(dir( moviepy.editor))
# def invert_green_blue(image):
#     return image[:,:,[0,2,1]]
# def invert_red_green(image):
#     return image[:,[0,2,1],:

clip1 = VideoFileClip( root + video_name + ".mp4").margin(1) # add 10px contour
clip1 = clip1.fx( vfx.colorx, 1.3)
# clip2 = clip1.fx( vfx.mirror_y)
# clip3 = clip1.fx( vfx.mirror_x)
# clip4 = clip1.fx( vfx.mirror_y)
# clip5 = clip1.fx( vfx.colorx, 1.3) # up 40%
# modifiedClip1 = clip1.fl_image( invert_red_green )
# modifiedClip2 = clip1.fl_image( invert_green_blue )
final_clip = clips_array([[clip1]])
final_clip.write_videofile(root+"fx_stack"+video_name +".mp4")

# %%
# %from moviepy.editor import *
# clip = (VideoFileClip( root+ video_name " + ".mp4")
# #         .fx( vfx.resize, width=460) # resize (keep aspect ratio)
# #         .fx( vfx.speedx, 2) # double the speed
#         .fx( vfx.colorx, 1.3)) # darken the picture

# clip.write_videofile("brighness_video_name.mp4")

# %%
# from moviepy.editor import VideoFileClip, concatenate_videoclips
# clip1 = VideoFileClip( root + video_name " + ".mp4")
# clip2 = VideoFileClip( root + video_name " + ".mp4").subclip(50,60)
# clip3 = VideoFileClip( root + video_name " + ".mp4")
# # final_clip = concatenate_videoclips([clip1,clip2,clip3])
# final_clip = clips_array([[clip1, clip2],
#                           [clip3, clip4]])
# final_clip.write_videofile(video_name+"_concatenation.mp4")
